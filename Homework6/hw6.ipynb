# %%
import numpy as np
import matplotlib.pyplot as plt
import math

def sinusoid(x, A, w):
    y = A * np.sin(w * x)
    return y

xdata = np.linspace(0, 2 * np.pi, 1000)

Avalues = np.array([])
for iteration in range(0, 5):
    randomNumber = np.random.uniform(0, 5)
    Avalues = np.append(Avalues, randomNumber)

wvalues = np.array([])
for iteration in range(0, 5):
    randomNumber = random.uniform(0, 2*math.pi)
    wvalues = np.append(wvalues, randomNumber)

plt.figure()

for index in range(0, 5):
    A = Avalues[index]
    w = wvalues[index]
    ydata = sinusoid(xdata, A, w)
    plt.plot(xdata, ydata, label=f"Sine Wave {index+1}")

plt.xlabel("x data")
plt.ylabel("y data")
plt.title("5 Different Sine Functions with Different Amplitudes and Frequencies")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

list1 = np.random.uniform(0, 100, 40)
list2 = np.random.uniform(0, 100, 40)

plt.figure(figsize=(10, 6))

plt.plot(list(range(len(list1))), list1, color="orange", linewidth=10, label="Line 1")
plt.plot(list(range(len(list2))), list2, color="red", linestyle="--", label="Line 2")
plt.xlabel("Indices")
plt.ylabel("Random Numbers")
plt.title("Random Numbers And Their Respective Indices")
plt.legend()
